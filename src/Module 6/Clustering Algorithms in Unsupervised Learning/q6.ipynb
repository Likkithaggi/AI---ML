# %%
# Question 5: Evaluating Clustering with Silhouette Score
# Description: Use Silhouette Score to evaluate the quality of clustering produced by K-Means. Experiment with different numbers of clusters.
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Generate synthetic dataset
X, _ = make_blobs(n_samples=500, centers=4, cluster_std=0.60, random_state=42)

# Try different numbers of clusters
silhouette_scores = []
cluster_range = range(2, 11)  # Silhouette Score is undefined for 1 cluster

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels)
    silhouette_scores.append(score)
    print(f"Silhouette Score for k={k}: {score:.4f}")

# Plot Silhouette Scores
plt.figure(figsize=(8, 5))
plt.plot(cluster_range, silhouette_scores, marker='o')
plt.title('Silhouette Score vs. Number of Clusters')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.grid(True)
plt.show()
# Out:
# Silhouette Score for k=2: 0.6187
# Silhouette Score for k=3: 0.8021
# Silhouette Score for k=4: 0.8757
# Silhouette Score for k=5: 0.7496
# Silhouette Score for k=6: 0.6040
# Silhouette Score for k=7: 0.4855
# Silhouette Score for k=8: 0.4783
# Silhouette Score for k=9: 0.4694
# Silhouette Score for k=10: 0.3293
